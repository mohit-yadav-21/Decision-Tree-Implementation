# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tree.base import DecisionTree
from metrics import *

np.random.seed(42)

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data'
data = pd.read_csv(url, delim_whitespace=True, header=None,
                 names=["mpg", "cylinders", "displacement", "horsepower", "weight",
                        "acceleration", "model year", "origin", "car name"])

data
# Out:
# C:\Users\bhavy\AppData\Local\Temp\ipykernel_1324\891556509.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(url, delim_whitespace=True, header=None,
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0      130.0  3504.0          12.0
# 1    15.0          8         350.0      165.0  3693.0          11.5
# 2    18.0          8         318.0      150.0  3436.0          11.0
# 3    16.0          8         304.0      150.0  3433.0          12.0
# 4    17.0          8         302.0      140.0  3449.0          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0      86.00  2790.0          15.6
# 394  44.0          4          97.0      52.00  2130.0          24.6
# 395  32.0          4         135.0      84.00  2295.0          11.6
# 396  28.0          4         120.0      79.00  2625.0          18.6
# 397  31.0          4         119.0      82.00  2720.0          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# 1            70       1          buick skylark 320
# 2            70       1         plymouth satellite
# 3            70       1              amc rebel sst
# 4            70       1                ford torino
# ..          ...     ...                        ...
# 393          82       1            ford mustang gl
# 394          82       2                  vw pickup
# 395          82       1              dodge rampage
# 396          82       1                ford ranger
# 397          82       1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
print(data.dtypes)
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight          float64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %%
data['horsepower'].isnull().sum()
# Out:
# 0

# %%
data['horsepower'].unique()
# Out:
# array(['130.0', '165.0', '150.0', '140.0', '198.0', '220.0', '215.0',
#        '225.0', '190.0', '170.0', '160.0', '95.00', '97.00', '85.00',
#        '88.00', '46.00', '87.00', '90.00', '113.0', '200.0', '210.0',
#        '193.0', '?', '100.0', '105.0', '175.0', '153.0', '180.0', '110.0',
#        '72.00', '86.00', '70.00', '76.00', '65.00', '69.00', '60.00',
#        '80.00', '54.00', '208.0', '155.0', '112.0', '92.00', '145.0',
#        '137.0', '158.0', '167.0', '94.00', '107.0', '230.0', '49.00',
#        '75.00', '91.00', '122.0', '67.00', '83.00', '78.00', '52.00',
#        '61.00', '93.00', '148.0', '129.0', '96.00', '71.00', '98.00',
#        '115.0', '53.00', '81.00', '79.00', '120.0', '152.0', '102.0',
#        '108.0', '68.00', '58.00', '149.0', '89.00', '63.00', '48.00',
#        '66.00', '139.0', '103.0', '125.0', '133.0', '138.0', '135.0',
#        '142.0', '77.00', '62.00', '132.0', '84.00', '64.00', '74.00',
#        '116.0', '82.00'], dtype=object)

# %%
data=data[data['horsepower'] != '?']
data['horsepower']=data['horsepower'].astype('float')
print(data.shape)
print(data.dtypes)
# Out:
# (392, 9)
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight          float64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object
# C:\Users\bhavy\AppData\Local\Temp\ipykernel_1324\3423172621.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['horsepower']=data['horsepower'].astype('float')

# %%
data.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
X=data.iloc[:,1:8].reset_index(drop=True)
y=data['mpg'].reset_index(drop=True)

# %%
for criteria in ["information_gain", "gini_index"]:
    tree = DecisionTree(criterion=criteria)
    tree.fit(X, y)
    y_hat = tree.predict(X)
    y_hat = pd.Series(y_hat)
    tree.plot()
    # print(y_hat,"\n",y)
    print("Criteria :", criteria)
    print("RMSE: ", rmse(y_hat, y))
    print("MAE: ", mae(y_hat, y))
    print("Accuracy: ", accuracy(y_hat, y))
# Out:
# <<<<<<<<<<<<<<<- START OF TREE ->>>>>>>>>>>>>>
#
# root -> ?(displacement > 190.50)
# ├────Yes -> ?(horsepower > 125.00)
# │    ├────Yes -> ?(model year > 76.00)
# │    │    ├────Yes -> ?(weight > 3947.50)
# │    │    │    ├────Yes -> ?(model year > 77.00)
# │    │    │    │    ├────Yes -> ?(displacement > 350.50)
# │    │    │    │    │    ├─── Yes: 16.00
# │    │    │    │    │    └─── No: 17.20
# │    │    │    │    └────No -> ?(displacement > 310.00)
# │    │    │    │    │    ├─── Yes: 15.70
# │    │    │    │    │    └─── No: 15.00
# │    │    │    └────No -> ?(acceleration > 13.20)
# │    │    │    │    ├────Yes -> ?(weight > 3835.00)
# │    │    │    │    │    ├─── Yes: 17.00
# │    │    │    │    │    └─── No: 17.83
# │    │    │    │    └────No -> ?(acceleration > 12.65)
# │    │    │    │    │    ├─── Yes: 19.32
# │    │    │    │    │    └─── No: 17.80
# │    │    └────No -> ?(weight > 4358.50)
# │    │    │    ├────Yes -> ?(model year > 74.00)
# │    │    │    │    ├────Yes -> ?(horsepower > 149.00)
# │    │    │    │    │    ├─── Yes: 16.17
# │    │    │    │    │    └─── No: 14.50
# │    │    │    │    └────No -> ?(model year > 70.00)
# │    │    │    │    │    ├─── Yes: 12.71
# │    │    │    │    │    └─── No: 10.80
# │    │    │    └────No -> ?(weight > 3533.50)
# │    │    │    │    ├────Yes -> ?(weight > 4132.00)
# │    │    │    │    │    ├─── Yes: 14.67
# │    │    │    │    │    └─── No: 13.96
# │    │    │    │    └────No -> ?(weight > 3416.00)
# │    │    │    │    │    ├─── Yes: 17.25
# │    │    │    │    │    └─── No: 14.00
# │    └────No -> ?(model year > 81.00)
# │    │    ├────Yes -> ?(displacement > 247.00)
# │    │    │    ├─── Yes: 38.00
# │    │    │    └─── No: 22.00
# │    │    └────No -> ?(model year > 75.00)
# │    │    │    ├────Yes -> ?(displacement > 327.00)
# │    │    │    │    ├────Yes -> ?(horsepower > 115.00)
# │    │    │    │    │    ├─── Yes: 23.00
# │    │    │    │    │    └─── No: 26.60
# │    │    │    │    └────No -> ?(weight > 3447.50)
# │    │    │    │    │    ├─── Yes: 18.22
# │    │    │    │    │    └─── No: 20.74
# │    │    │    └────No -> ?(acceleration > 16.50)
# │    │    │    │    ├────Yes -> ?(displacement > 241.00)
# │    │    │    │    │    ├─── Yes: 15.50
# │    │    │    │    │    └─── No: 18.00
# │    │    │    │    └────No -> ?(displacement > 212.50)
# │    │    │    │    │    ├─── Yes: 18.47
# │    │    │    │    │    └─── No: 20.83
# └────No -> ?(horsepower > 70.00)
# │    ├────Yes -> ?(model year > 78.00)
# │    │    ├────Yes -> ?(weight > 2580.00)
# │    │    │    ├────Yes -> ?(origin > 2.00)
# │    │    │    │    ├────Yes -> ?(weight > 2920.00)
# │    │    │    │    │    ├─── Yes: 24.20
# │    │    │    │    │    └─── No: 30.73
# │    │    │    │    └────No -> ?(horsepower > 83.00)
# │    │    │    │    │    ├─── Yes: 26.31
# │    │    │    │    │    └─── No: 28.26
# │    │    │    └────No -> ?(cylinders > 3.50)
# │    │    │    │    ├────Yes -> ?(acceleration > 15.50)
# │    │    │    │    │    ├─── Yes: 31.45
# │    │    │    │    │    └─── No: 34.63
# │    │    │    │    └─── No: 23.70
# │    │    └────No -> ?(weight > 2300.00)
# │    │    │    ├────Yes -> ?(weight > 2861.50)
# │    │    │    │    ├────Yes -> ?(displacement > 159.50)
# │    │    │    │    │    ├─── Yes: 16.93
# │    │    │    │    │    └─── No: 20.12
# │    │    │    │    └────No -> ?(model year > 73.00)
# │    │    │    │    │    ├─── Yes: 24.00
# │    │    │    │    │    └─── No: 21.94
# │    │    │    └────No -> ?(weight > 2087.50)
# │    │    │    │    ├────Yes -> ?(cylinders > 3.50)
# │    │    │    │    │    ├─── Yes: 26.37
# │    │    │    │    │    └─── No: 18.00
# │    │    │    │    └────No -> ?(acceleration > 14.50)
# │    │    │    │    │    ├─── Yes: 32.50
# │    │    │    │    │    └─── No: 29.50
# │    └────No -> ?(model year > 77.00)
# │    │    ├────Yes -> ?(horsepower > 48.00)
# │    │    │    ├────Yes -> ?(weight > 2130.00)
# │    │    │    │    ├────Yes -> ?(displacement > 98.00)
# │    │    │    │    │    ├─── Yes: 33.97
# │    │    │    │    │    └─── No: 30.80
# │    │    │    │    └────No -> ?(weight > 2067.50)
# │    │    │    │    │    ├─── Yes: 39.27
# │    │    │    │    │    └─── No: 35.70
# │    │    │    └────No -> ?(weight > 2035.00)
# │    │    │    │    ├────Yes -> ?(weight > 2210.00)
# │    │    │    │    │    ├─── Yes: 43.40
# │    │    │    │    │    └─── No: 44.30
# │    │    │    │    └─── No: 43.10
# │    │    └────No -> ?(origin > 2.00)
# │    │    │    ├────Yes -> ?(weight > 1631.00)
# │    │    │    │    ├────Yes -> ?(acceleration > 16.65)
# │    │    │    │    │    ├─── Yes: 32.11
# │    │    │    │    │    └─── No: 30.50
# │    │    │    │    └─── No: 35.00
# │    │    │    └────No -> ?(weight > 1829.50)
# │    │    │    │    ├────Yes -> ?(weight > 2119.00)
# │    │    │    │    │    ├─── Yes: 24.50
# │    │    │    │    │    └─── No: 28.21
# │    │    │    │    └─── No: 36.00
#
# <<<<<<<<<<<<<<<- END OF TREE ->>>>>>>>>>>>>>
#
# Criteria : information_gain
# 2.178138849149237
# RMSE:  None
# 1.5952216438662672
# MAE:  None
# Accuracy:  0.017857142857142856
#
# <<<<<<<<<<<<<<<- START OF TREE ->>>>>>>>>>>>>>
#
# root -> ?(displacement > 190.50)
# ├────Yes -> ?(horsepower > 125.00)
# │    ├────Yes -> ?(model year > 76.00)
# │    │    ├────Yes -> ?(weight > 3947.50)
# │    │    │    ├────Yes -> ?(model year > 77.00)
# │    │    │    │    ├────Yes -> ?(displacement > 350.50)
# │    │    │    │    │    ├─── Yes: 16.00
# │    │    │    │    │    └─── No: 17.20
# │    │    │    │    └────No -> ?(displacement > 310.00)
# │    │    │    │    │    ├─── Yes: 15.70
# │    │    │    │    │    └─── No: 15.00
# │    │    │    └────No -> ?(acceleration > 13.20)
# │    │    │    │    ├────Yes -> ?(weight > 3835.00)
# │    │    │    │    │    ├─── Yes: 17.00
# │    │    │    │    │    └─── No: 17.83
# │    │    │    │    └────No -> ?(acceleration > 12.65)
# │    │    │    │    │    ├─── Yes: 19.32
# │    │    │    │    │    └─── No: 17.80
# │    │    └────No -> ?(weight > 4358.50)
# │    │    │    ├────Yes -> ?(model year > 74.00)
# │    │    │    │    ├────Yes -> ?(horsepower > 149.00)
# │    │    │    │    │    ├─── Yes: 16.17
# │    │    │    │    │    └─── No: 14.50
# │    │    │    │    └────No -> ?(model year > 70.00)
# │    │    │    │    │    ├─── Yes: 12.71
# │    │    │    │    │    └─── No: 10.80
# │    │    │    └────No -> ?(weight > 3533.50)
# │    │    │    │    ├────Yes -> ?(weight > 4132.00)
# │    │    │    │    │    ├─── Yes: 14.67
# │    │    │    │    │    └─── No: 13.96
# │    │    │    │    └────No -> ?(weight > 3416.00)
# │    │    │    │    │    ├─── Yes: 17.25
# │    │    │    │    │    └─── No: 14.00
# │    └────No -> ?(model year > 81.00)
# │    │    ├────Yes -> ?(displacement > 247.00)
# │    │    │    ├─── Yes: 38.00
# │    │    │    └─── No: 22.00
# │    │    └────No -> ?(model year > 75.00)
# │    │    │    ├────Yes -> ?(displacement > 327.00)
# │    │    │    │    ├────Yes -> ?(horsepower > 115.00)
# │    │    │    │    │    ├─── Yes: 23.00
# │    │    │    │    │    └─── No: 26.60
# │    │    │    │    └────No -> ?(weight > 3447.50)
# │    │    │    │    │    ├─── Yes: 18.22
# │    │    │    │    │    └─── No: 20.74
# │    │    │    └────No -> ?(acceleration > 16.50)
# │    │    │    │    ├────Yes -> ?(displacement > 241.00)
# │    │    │    │    │    ├─── Yes: 15.50
# │    │    │    │    │    └─── No: 18.00
# │    │    │    │    └────No -> ?(displacement > 212.50)
# │    │    │    │    │    ├─── Yes: 18.47
# │    │    │    │    │    └─── No: 20.83
# └────No -> ?(horsepower > 70.00)
# │    ├────Yes -> ?(model year > 78.00)
# │    │    ├────Yes -> ?(weight > 2580.00)
# │    │    │    ├────Yes -> ?(origin > 2.00)
# │    │    │    │    ├────Yes -> ?(weight > 2920.00)
# │    │    │    │    │    ├─── Yes: 24.20
# │    │    │    │    │    └─── No: 30.73
# │    │    │    │    └────No -> ?(horsepower > 83.00)
# │    │    │    │    │    ├─── Yes: 26.31
# │    │    │    │    │    └─── No: 28.26
# │    │    │    └────No -> ?(cylinders > 3.50)
# │    │    │    │    ├────Yes -> ?(acceleration > 15.50)
# │    │    │    │    │    ├─── Yes: 31.45
# │    │    │    │    │    └─── No: 34.63
# │    │    │    │    └─── No: 23.70
# │    │    └────No -> ?(weight > 2300.00)
# │    │    │    ├────Yes -> ?(weight > 2861.50)
# │    │    │    │    ├────Yes -> ?(displacement > 159.50)
# │    │    │    │    │    ├─── Yes: 16.93
# │    │    │    │    │    └─── No: 20.12
# │    │    │    │    └────No -> ?(model year > 73.00)
# │    │    │    │    │    ├─── Yes: 24.00
# │    │    │    │    │    └─── No: 21.94
# │    │    │    └────No -> ?(weight > 2087.50)
# │    │    │    │    ├────Yes -> ?(cylinders > 3.50)
# │    │    │    │    │    ├─── Yes: 26.37
# │    │    │    │    │    └─── No: 18.00
# │    │    │    │    └────No -> ?(acceleration > 14.50)
# │    │    │    │    │    ├─── Yes: 32.50
# │    │    │    │    │    └─── No: 29.50
# │    └────No -> ?(model year > 77.00)
# │    │    ├────Yes -> ?(horsepower > 48.00)
# │    │    │    ├────Yes -> ?(weight > 2130.00)
# │    │    │    │    ├────Yes -> ?(displacement > 98.00)
# │    │    │    │    │    ├─── Yes: 33.97
# │    │    │    │    │    └─── No: 30.80
# │    │    │    │    └────No -> ?(weight > 2067.50)
# │    │    │    │    │    ├─── Yes: 39.27
# │    │    │    │    │    └─── No: 35.70
# │    │    │    └────No -> ?(weight > 2035.00)
# │    │    │    │    ├────Yes -> ?(weight > 2210.00)
# │    │    │    │    │    ├─── Yes: 43.40
# │    │    │    │    │    └─── No: 44.30
# │    │    │    │    └─── No: 43.10
# │    │    └────No -> ?(origin > 2.00)
# │    │    │    ├────Yes -> ?(weight > 1631.00)
# │    │    │    │    ├────Yes -> ?(acceleration > 16.65)
# │    │    │    │    │    ├─── Yes: 32.11
# │    │    │    │    │    └─── No: 30.50
# │    │    │    │    └─── No: 35.00
# │    │    │    └────No -> ?(weight > 1829.50)
# │    │    │    │    ├────Yes -> ?(weight > 2119.00)
# │    │    │    │    │    ├─── Yes: 24.50
# │    │    │    │    │    └─── No: 28.21
# │    │    │    │    └─── No: 36.00
#
# <<<<<<<<<<<<<<<- END OF TREE ->>>>>>>>>>>>>>
#
# Criteria : gini_index
# 2.178138849149237
# RMSE:  None
# 1.5952216438662672
# MAE:  None
# Accuracy:  0.017857142857142856

# %%
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.3, random_state=42)
model=tree.DecisionTreeRegressor(max_depth=5)
model.fit(X_train,y_train)
print("Training accuracy =", model.score(X_train,y_train))
# Out:
# Training accuracy = 0.9379113806788827

# %%
y_hat=model.predict(X_test)
print("Testing accuracy =", model.score(X_test,y_test))
print("RMSE =", np.sqrt(mean_squared_error(y_hat,y_test)))
print("MAE =", mean_absolute_error(y_hat,y_test))
# Out:
# Testing accuracy = 0.8094429117177016
# RMSE = 3.1751205206902453
# MAE = 2.2961593623269154

# %%
print(tree.export_text(model, feature_names=X.columns))
# Out:
# |--- displacement <= 198.50
# |   |--- horsepower <= 84.50
# |   |   |--- model year <= 76.50
# |   |   |   |--- weight <= 2099.50
# |   |   |   |   |--- origin <= 2.50
# |   |   |   |   |   |--- value: [29.42]
# |   |   |   |   |--- origin >  2.50
# |   |   |   |   |   |--- value: [32.22]
# |   |   |   |--- weight >  2099.50
# |   |   |   |   |--- acceleration <= 16.75
# |   |   |   |   |   |--- value: [26.44]
# |   |   |   |   |--- acceleration >  16.75
# |   |   |   |   |   |--- value: [24.08]
# |   |   |--- model year >  76.50
# |   |   |   |--- displacement <= 94.00
# |   |   |   |   |--- weight <= 2077.50
# |   |   |   |   |   |--- value: [36.54]
# |   |   |   |   |--- weight >  2077.50
# |   |   |   |   |   |--- value: [43.78]
# |   |   |   |--- displacement >  94.00
# |   |   |   |   |--- weight <= 2375.00
# |   |   |   |   |   |--- value: [33.35]
# |   |   |   |   |--- weight >  2375.00
# |   |   |   |   |   |--- value: [29.24]
# |   |--- horsepower >  84.50
# |   |   |--- model year <= 78.50
# |   |   |   |--- weight <= 2781.00
# |   |   |   |   |--- acceleration <= 18.00
# |   |   |   |   |   |--- value: [24.41]
# |   |   |   |   |--- acceleration >  18.00
# |   |   |   |   |   |--- value: [19.67]
# |   |   |   |--- weight >  2781.00
# |   |   |   |   |--- origin <= 1.50
# |   |   |   |   |   |--- value: [23.40]
# |   |   |   |   |--- origin >  1.50
# |   |   |   |   |   |--- value: [19.22]
# |   |   |--- model year >  78.50
# |   |   |   |--- weight <= 2570.50
# |   |   |   |   |--- horsepower <= 96.00
# |   |   |   |   |   |--- value: [34.83]
# |   |   |   |   |--- horsepower >  96.00
# |   |   |   |   |   |--- value: [23.70]
# |   |   |   |--- weight >  2570.50
# |   |   |   |   |--- horsepower <= 126.00
# |   |   |   |   |   |--- value: [26.79]
# |   |   |   |   |--- horsepower >  126.00
# |   |   |   |   |   |--- value: [32.70]
# |--- displacement >  198.50
# |   |--- horsepower <= 127.00
# |   |   |--- model year <= 81.50
# |   |   |   |--- model year <= 77.50
# |   |   |   |   |--- displacement <= 231.50
# |   |   |   |   |   |--- value: [20.23]
# |   |   |   |   |--- displacement >  231.50
# |   |   |   |   |   |--- value: [17.65]
# |   |   |   |--- model year >  77.50
# |   |   |   |   |--- displacement <= 259.00
# |   |   |   |   |   |--- value: [20.25]
# |   |   |   |   |--- displacement >  259.00
# |   |   |   |   |   |--- value: [24.50]
# |   |   |--- model year >  81.50
# |   |   |   |--- value: [38.00]
# |   |--- horsepower >  127.00
# |   |   |--- model year <= 76.50
# |   |   |   |--- weight <= 4715.50
# |   |   |   |   |--- horsepower <= 152.50
# |   |   |   |   |   |--- value: [14.65]
# |   |   |   |   |--- horsepower >  152.50
# |   |   |   |   |   |--- value: [13.54]
# |   |   |   |--- weight >  4715.50
# |   |   |   |   |--- displacement <= 343.50
# |   |   |   |   |   |--- value: [9.00]
# |   |   |   |   |--- displacement >  343.50
# |   |   |   |   |   |--- value: [12.00]
# |   |   |--- model year >  76.50
# |   |   |   |--- weight <= 3947.50
# |   |   |   |   |--- acceleration <= 13.30
# |   |   |   |   |   |--- value: [18.70]
# |   |   |   |   |--- acceleration >  13.30
# |   |   |   |   |   |--- value: [17.43]
# |   |   |   |--- weight >  3947.50
# |   |   |   |   |--- model year <= 77.50
# |   |   |   |   |   |--- value: [15.60]
# |   |   |   |   |--- model year >  77.50
# |   |   |   |   |   |--- value: [16.50]
